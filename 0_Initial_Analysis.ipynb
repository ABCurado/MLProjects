# %% [markdown]
# ## Initial exploratory data analysis

# %%
import pandas as pd

# %% [markdown]
# ![panda](data:image/jpeg;base64,...)

# %%
data = pd.read_excel("ml_project1_data.xlsx")

# %% [markdown]
# __Lets check which variables there are and how many rows__

# %%
print(str(len(data.keys())) + " variables")
print(data.keys().values)
print(str(len(data)) + " observations")
# Out:
# 29 variables
# ['ID' 'Year_Birth' 'Education' 'Marital_Status' 'Income' 'Kidhome'
#  'Teenhome' 'Dt_Customer' 'Recency' 'MntWines' 'MntFruits'
#  'MntMeatProducts' 'MntFishProducts' 'MntSweetProducts' 'MntGoldProds'
#  'NumDealsPurchases' 'NumWebPurchases' 'NumCatalogPurchases'
#  'NumStorePurchases' 'NumWebVisitsMonth' 'AcceptedCmp3' 'AcceptedCmp4'
#  'AcceptedCmp5' 'AcceptedCmp1' 'AcceptedCmp2' 'Complain' 'Z_CostContact'
#  'Z_Revenue' 'Response']
# 2240 observations

# %% [markdown]
# __Missing Values__

# %%
def missing_values_reporter(df):    
    na_count = df.isna().sum() 
    ser = na_count[na_count > 0]
    return pd.DataFrame({"N missings": ser, "% missings": ser.divide(df.shape[0])})

missing_values_reporter(data)
# Out:
#         N missings  % missings
# Income          24    0.010714

# %% [markdown]
# Not so many missing rows. Cool its not gonna be like Data Mining

# %% [markdown]
# ### Lets go a bit in depth into the variables

# %%
for variable in data:
    if set(data[variable].unique()) == set([0,1]):
        data[variable] = data[variable].astype(bool)

# %% [markdown]
# Convert boolean variables to numpy bool type

# %%
data.describe()
# Out:
#                  ID   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
data.describe(include=["object"])
# Out:
#          Education Marital_Status Dt_Customer
# count         2240           2240        2240
# unique           5              8         663
# top     Graduation        Married  2012-08-31
# freq          1127            864          12

# %%
data.describe(include=bool)
# Out:
#        AcceptedCmp3 AcceptedCmp4 AcceptedCmp5 AcceptedCmp1 AcceptedCmp2  \
# count          2240         2240         2240         2240         2240
# unique            2            2            2            2            2
# top           False        False        False        False        False
# freq           2077         2073         2077         2096         2210
#
#        Complain Response
# count      2240     2240
# unique        2        2
# top       False    False
# freq       2219     1906
