# %%
# !python3 solution_finder.py
# Out:
# Using TensorFlow backend.
# 480
# Number of cpu cores: 8
#
# Algorithm,Parameters,Preprocessing Pipeline,Scaling,Sampling,time,precision,recall,result_profit
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.425
# LinearRegression: 0.425
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.383
# LinearRegression: 0.391
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.377
# LinearSVC: 0.0
# LogisticRegression: 0.0
# LogisticRegression: 0.382
# GaussianNB: 0.195
# LinearSVC: 0.382
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.388
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.419
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.41
# LinearRegression: 0.379
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.382
# LinearRegression: 0.389
# LogisticRegression: 0.379
# LinearSVC: 0.0
# LogisticRegression: 0.0
# GaussianNB: 0.215
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.36
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.382
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.431
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.173
# LogisticRegression: 0.0
# GaussianNB: 0.203
# LinearRegression: 0.34
# LinearSVC: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LogisticRegression: 0.388
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.37
# LinearRegression: 0.376
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.371
# LogisticRegression: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.163
# GaussianNB: 0.197
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.0
# LogisticRegression: 0.354
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.374
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.352
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.38
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.378
# LogisticRegression: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.166
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.236
# LinearSVC: -1.632
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.369
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LogisticRegression: 0.34
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.37
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.327
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.391
# LogisticRegression: 0.0
# GaussianNB: 0.156
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.211
# LinearSVC: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.407
# LogisticRegression: 0.37
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.363
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.319
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LogisticRegression: 0.266
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.214
# LinearSVC: -0.479
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.168
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LogisticRegression: 0.366
# SVC: 0.358
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.394
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LogisticRegression: -0.482
# GaussianNB: 0.177
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: -0.136
# GaussianNB: 0.19
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LogisticRegression: 0.354
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SVC: -16.625
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.361
# LogisticRegression: -0.031
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.192
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: -0.035
# GaussianNB: 0.209
# LogisticRegression: 0.415
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SVC: -0.654
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.408
# LogisticRegression: 0.25
# GaussianNB: 0.185
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.212
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LogisticRegression: 0.364
# LinearSVC: -0.17
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SVC: 0.361
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.362
# GaussianNB: 0.167
# LogisticRegression: 0.334
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.198
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LogisticRegression: 0.339
# SVC: 0.361
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.119
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.188
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.337
# LogisticRegression: -0.656
# GaussianNB: 0.183
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SVC: -34.625
# LogisticRegression: 0.332
# LinearSVC: -0.045
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.416
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.098
# LinearRegression: 0.381
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.325
# LogisticRegression: 0.406
# LinearRegression: 0.368
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.177
# SVC: 0.364
# SVC: 0.318
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.416
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.087
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.393
# LinearSVC: 0.393
# SVC: -34.625
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.213
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LogisticRegression: 0.308
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearRegression: 0.377
# SVC: -0.237
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.084
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.375
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SVC: -0.301
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LogisticRegression: 0.399
# SVC: 0.0
# SVC: 0.26
# SGDClassifier: 0.342
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.12
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.42
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SVC: 0.338
# LogisticRegression: 0.365
# SGDClassifier: 0.277
# SVC: 0.284
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SVC: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.352
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.128
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SVC: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LogisticRegression: 0.332
# SGDClassifier: 0.234
# SVC: 0.345
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# GaussianNB: 0.086
# LinearSVC: 0.333
# SVC: 0.283
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SVC: 0.0
# LogisticRegression: 0.272
# DecisionTreeClassifier: 0.137
# SGDClassifier: 0.355
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SVC: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# LinearSVC: 0.314
# SVC: -0.683
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.122
# SVC: 0.0
# DecisionTreeClassifier: 0.13
# SVC: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: 0.281
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.201
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SVC: 0.0
# DecisionTreeClassifier: 0.224
# SGDClassifier: 0.254
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SVC: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: 0.201
# RandomForestClassifier: 0.201
# DecisionTreeClassifier: 0.156
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.171
# SVC: 0.0
# SGDClassifier: 0.0
# SGDClassifier: 0.275
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.194
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.162
# SGDClassifier: 0.0
# SVC: 0.0
# SGDClassifier: 0.28
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: -1.297
# DecisionTreeClassifier: 0.211
# RandomForestClassifier: -0.839
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.174
# SVC: 0.0
# SGDClassifier: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: 0.355
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.181
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.117
# SVC: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: -0.055
# SGDClassifier: 0.262
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: -0.175
# RandomForestClassifier: -0.068
# DecisionTreeClassifier: 0.138
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.202
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: -0.063
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: 0.256
# DecisionTreeClassifier: 0.127
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: -0.03
# DecisionTreeClassifier: 0.246
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: 0.272
# DecisionTreeClassifier: 0.173
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: 0.059
# SGDClassifier: 0.089
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: 0.128
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.164
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: 0.296
# DecisionTreeClassifier: 0.15
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.17
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.122
# SGDClassifier: 0.268
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: 0.015
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.163
# RandomForestClassifier: 0.235
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.312
# DecisionTreeClassifier: 0.144
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: 0.294
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: 0.321
# SGDClassifier: 0.085
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.108
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: 0.244
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: 0.045
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.168
# RandomForestClassifier: -1.553
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: -1.553
# RandomForestClassifier: 0.203
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: 0.276
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: -1.11
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.25
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# SGDClassifier: 0.327
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.156
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: -1.09
# DecisionTreeClassifier: 0.227
# RandomForestClassifier: 0.214
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.347
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# DecisionTreeClassifier: 0.173
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: -1.057
# RandomForestClassifier: 0.103
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.294
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.316
# RandomForestRegressor_depth3: 0.25
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: 0.055
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: 0.248
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.258
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.337
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.335
# RandomForestClassifier: 0.172
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.321
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.254
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: 0.324
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.346
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: 0.321
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.238
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.314
# RandomForestClassifier: -1.615
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: -1.444
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.347
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.25
# RandomForestRegressor_depth7: 0.304
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.324
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.232
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: 0.024
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.234
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.231
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.349
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.246
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: -1.442
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.29
# RandomForestRegressor_depth3: 0.25
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.234
# RandomForestClassifier: -0.236
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.362
# RandomForestRegressor_depth3: 0.239
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.31
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.261
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: 0.147
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.232
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.311
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.253
# RandomForestRegressor_depth3: 0.231
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: 0.26
# RandomForestRegressor_depth14: 0.343
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.334
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.309
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestClassifier: -2.25
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.241
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.325
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.231
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.302
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.293
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.348
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.272
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.33
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.331
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.362
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.224
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.293
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.314
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.317
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.23
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.293
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.256
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.309
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.329
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.359
# RandomForestRegressor_depth3: 0.213
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.205
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.296
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.29
# RandomForestRegressor_depth14: 0.348
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.23
# XGBClassifier: 0.325
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.343
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.308
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth3: 0.217
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.316
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.312
# RandomForestRegressor_depth7: 0.317
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_10_layers: 0.251
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_10_layers: 0.26
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.347
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_10_layers: 0.31
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.342
# MLPClassifier_10_layers: 0.276
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.295
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_10_layers: 0.235
# RandomForestRegressor_depth7: 0.327
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.283
# MLPClassifier_10_layers: 0.274
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_10_layers: 0.284
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.321
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_10_layers: 0.33
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.275
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_10_layers: 0.272
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.348
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.315
# MLPClassifier_10_layers: 0.265
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.314
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_10_layers: 0.303
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_10_layers: 0.314
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth7: 0.308
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.365
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.345
# RandomForestRegressor_depth7: 0.332
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_10_layers: 0.253
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_10_layers: 0.066
# RandomForestRegressor_depth3: 0.25
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# ...
# RandomForestRegressor_depth14: 0.328
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.284
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.218
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.406
# MLPClassifier_5_layers: 0.283
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.293
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.428
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.268
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.297
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.32
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.339
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.403
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.186
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.343
# KerasNN_3layers: 0.404
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.294
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.288
# MLPClassifier_5_layers: 0.289
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# 2019-04-27 21:37:22.180681: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-04-27 21:37:22.231437: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1800000000 Hz
# 2019-04-27 21:37:22.232943: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55d7b46fe380 executing computations on platform Host. Devices:
# 2019-04-27 21:37:22.233114: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# KerasNN_3layers: 0.422
# KerasNN_3layers: 0.404
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.319
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.236
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.29
# RandomForestRegressor_depth14: 0.342
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.477
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.242
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.131
# KerasNN_3layers: 0.418
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.437
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: -8.141
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: -0.378
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.433
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.407
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.123
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.41
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.266
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.462
# XGBClassifier: 0.245
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: 0.186
# RandomForestRegressor_depth14: 0.336
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# MLPClassifier_5_layers: -6.045
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 2019-04-27 21:42:32.080034: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-04-27 21:42:32.127351: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1800000000 Hz
# 2019-04-27 21:42:32.128041: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55d7b3349300 executing computations on platform Host. Devices:
# 2019-04-27 21:42:32.128096: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# KerasNN_3layers: 0.162
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.395
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.407
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# RandomForestRegressor_depth14: 0.343
# KerasNN_3layers: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.188
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.45
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.279
# XGBClassifier: 0.295
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.393
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.428
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.161
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.159
# KerasNN_3layers: 0.422
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.435
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.17
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.428
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.18
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.393
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.25
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.315
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.383
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.424
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.19
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: -0.047
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: 0.413
# KerasNN_12layers: 0.376
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: -1.875
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.139
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.269
# XGBClassifier: -1
# KerasNN_3layers: -1.723
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.451
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.063
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: -1
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: -1
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: -0.984
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: -1
# KerasNN_12layers: 0.393
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: -1
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: -0.046
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.437
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_3layers: -1.628
# KerasNN_12layers: 0.0
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.449
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.102
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.35
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# XGBClassifier: 0.269
# KerasNN_12layers: 0.0
# KerasNN_12layers: 0.392
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.391
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.389
# Removing outliers using the IQR method with 2 quartiles would lead to a change of data size:  -0.2423146473779385
# KerasNN_12layers: 0.372

# %%
models = [
        ("KerasNN_3l_6n_oa_iu_lm_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="adam",init="uniform",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_6l_6n_oa_iu_lm_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="adam",init="uniform",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_3l_12n_oa_iu_lm_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="adam",init="uniform",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_6l_12n_oa_iu_lm_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="adam",init="uniform",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_3l_6n_or_iu_lm_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="rmsprop",init="uniform",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_6l_6n_or_iu_lm_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="rmsprop",init="uniform",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_3l_12n_or_iu_lm_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="rmsprop",init="uniform",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_6l_12n_or_iu_lm_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="rmsprop",init="uniform",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_3l_6n_oa_ih_lm_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="adam",init="he_normal",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_6l_6n_oa_ih_lm_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="adam",init="he_normal",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_3l_12n_oa_ih_lm_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="adam",init="he_normal",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_6l_12n_oa_ih_lm_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="adam",init="he_normal",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_3l_6n_or_ih_lm_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="rmsprop",init="he_normal",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_6l_6n_or_ih_lm_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="rmsprop",init="he_normal",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_3l_12n_or_ih_lm_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="rmsprop",init="he_normal",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_6l_12n_or_ih_lm_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="rmsprop",init="he_normal",loss="mean_squared_error",r_dropout=0.2)"),
    ("KerasNN_3l_6n_oa_iu_lb_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="adam",init="uniform",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_6l_6n_oa_iu_lb_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="adam",init="uniform",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_3l_12n_oa_iu_lb_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="adam",init="uniform",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_6l_12n_oa_iu_lb_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="adam",init="uniform",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_3l_6n_or_iu_lb_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="rmsprop",init="uniform",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_6l_6n_or_iu_lb_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="rmsprop",init="uniform",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_3l_12n_or_iu_lb_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="rmsprop",init="uniform",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_6l_12n_or_iu_lb_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="rmsprop",init="uniform",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_3l_6n_oa_ih_lb_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="adam",init="he_normal",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_6l_6n_oa_ih_lb_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="adam",init="he_normal",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_3l_12n_oa_ih_lb_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="adam",init="he_normal",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_6l_12n_oa_ih_lb_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="adam",init="he_normal",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_3l_6n_or_ih_lb_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="rmsprop",init="he_normal",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_6l_6n_or_ih_lb_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="rmsprop",init="he_normal",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_3l_12n_or_ih_lb_d2" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="rmsprop",init="he_normal",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_6l_12n_or_ih_lb_d2" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="rmsprop",init="he_normal",loss="binary_crossentropy",r_dropout=0.2)"),
    ("KerasNN_3l_6n_oa_iu_lm_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="adam",init="uniform",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_6l_6n_oa_iu_lm_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="adam",init="uniform",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_3l_12n_oa_iu_lm_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="adam",init="uniform",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_6l_12n_oa_iu_lm_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="adam",init="uniform",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_3l_6n_or_iu_lm_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="rmsprop",init="uniform",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_6l_6n_or_iu_lm_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="rmsprop",init="uniform",loss="mean_squared_error",r_dropout=0.4)")
]

# %% [markdown]
# ### Antonio model run

# %%
models = [
        ("KerasNN_6l_12n_or_iu_lm_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="rmsprop",init="uniform",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_3l_6n_oa_ih_lm_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="adam",init="he_normal",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_6l_6n_oa_ih_lm_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="adam",init="he_normal",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_3l_12n_oa_ih_lm_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="adam",init="he_normal",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_6l_12n_oa_ih_lm_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="adam",init="he_normal",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_3l_6n_or_ih_lm_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="rmsprop",init="he_normal",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_6l_6n_or_ih_lm_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="rmsprop",init="he_normal",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_3l_12n_or_ih_lm_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="rmsprop",init="he_normal",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_6l_12n_or_ih_lm_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="rmsprop",init="he_normal",loss="mean_squared_error",r_dropout=0.4)"),
    ("KerasNN_3l_6n_oa_iu_lb_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="adam",init="uniform",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_6l_6n_oa_iu_lb_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="adam",init="uniform",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_3l_12n_oa_iu_lb_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="adam",init="uniform",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_6l_12n_oa_iu_lb_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="adam",init="uniform",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_3l_6n_or_iu_lb_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="rmsprop",init="uniform",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_6l_6n_or_iu_lb_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="rmsprop",init="uniform",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_3l_12n_or_iu_lb_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="rmsprop",init="uniform",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_6l_12n_or_iu_lb_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="rmsprop",init="uniform",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_3l_6n_oa_ih_lb_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="adam",init="he_normal",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_6l_6n_oa_ih_lb_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="adam",init="he_normal",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_3l_12n_oa_ih_lb_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="adam",init="he_normal",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_6l_12n_oa_ih_lb_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="adam",init="he_normal",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_3l_6n_or_ih_lb_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=6, optimizer="rmsprop",init="he_normal",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_6l_6n_or_ih_lb_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=6, optimizer="rmsprop",init="he_normal",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_3l_12n_or_ih_lb_d4" , "KerasNN_not_fitted(n_layers=3, n_neurons=12, optimizer="rmsprop",init="he_normal",loss="binary_crossentropy",r_dropout=0.4)"),
    ("KerasNN_6l_12n_or_ih_lb_d4" , "KerasNN_not_fitted(n_layers=6, n_neurons=12, optimizer="rmsprop",init="he_normal",loss="binary_crossentropy",r_dropout=0.4)")
