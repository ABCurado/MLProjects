# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !ls log_files2
# Out:
# 'fitness_&_operator_probs_geno_log.csv'    results_geno_log.csv
# 'fitness_&_operator_probs_GP_log.csv'	   results_GSGP_log.csv
# 'fitness_&_operator_probs_naive_log.csv'   results_naive_log.csv
# 'fitness_&_operator_probs_pheno_log.csv'   results_operators_log.csv
#  programs_GP_log.csv			   results_pheno_log.csv
#  results_algos_log.csv

# %%
df = pd.read_csv('log_files2/results_operators_log.csv') 
df.head()
# Out:
#    Seed          Algorithm            time  mean_s_error  explained_variance  \
# 0     1  GP_normal_fitness  0:00:14.295953      2.099398           -1.664867
# 1     0         GP_fitness  0:00:15.808751      1.799009           -1.213527
# 2     0     GP_no_operator  0:00:19.240520      1.926161           -0.506444
# 3     0      GP_tournament  0:00:19.595506      1.926161           -0.506444
# 4     0  GP_pheno_operator  0:00:19.664632      1.926161           -0.506444
#
#    final_tree_size
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df[df['Algorithm'].isin(['GP_rank','GP_roulette','GP_fitness','GP_no_operator'])].groupby('Algorithm').describe().T
# Out:
# Algorithm                 GP_fitness  GP_no_operator    GP_rank  GP_roulette
# Seed               count    5.000000        5.000000   5.000000     5.000000
#                    mean     2.000000        2.000000   2.000000     2.000000
#                    std      1.581139        1.581139   1.581139     1.581139
#                    min      0.000000        0.000000   0.000000     0.000000
#                    25%      1.000000        1.000000   1.000000     1.000000
#                    50%      2.000000        2.000000   2.000000     2.000000
#                    75%      3.000000        3.000000   3.000000     3.000000
#                    max      4.000000        4.000000   4.000000     4.000000
# explained_variance count    5.000000        5.000000   5.000000     5.000000
#                    mean    -2.475681       -3.726917  -0.842442   -13.988193
#                    std      2.742467        3.665343   1.184055    14.430276
# ...
